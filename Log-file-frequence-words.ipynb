# %%
# %config IPCompleter.greedy=True

import os
import sys
import nltk 
import io
import re
import csv
import random
import pandas as pd
import numpy as np
import string # to process standard python strings
from bs4 import BeautifulSoup as bs
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
'''
nltk.download('book', download_dir='/home/amanda/jupiter_notebooks/nltk_data/book')
from nltk.book import *
'''

def config_environment():
    #in the future, get home_dir from system or read/load NLTK_DATA path from input() --> STDIN do Python
    NLTK_DATA = r'/home/amanda/jupiter_notebooks/nltk_data' # User-specified locations
    nltk.data.path.append(NLTK_DATA)
    os.makedirs(NLTK_DATA, exist_ok=True)

def download_nltk_packages():
    #in the future, read/load nltk_packages names from input() --> STDIN do Python
    nltk_packages = ['punkt', 'wordnet']
    for package in nltk_packages:
        nltk.download(package, download_dir='%s/%s' % (NLTK_DATA, package))


config_environment()
#download_nltk_packages()
filename = r'/home/amanda/jupiter_notebooks/parse_log_files_to_csv/dumpState-UHM.log' #in the future, read/load filename from input() --> STDIN do Python
if not os.path.isfile(filename):
    print('Arquivo não encontrado.')
else:
    log_file = open(filename, 'rU', errors='ignore') # 'U'niversal: ignore newlines characters as '\n'

#type(log_file)

log_content = log_file.read()
log_content = log_content.lower()

#print(log_content)
tokens = wt(log_content)
#print()
#print()
#print(tokens)

tfidf_vec = TfidfVectorizer(tokenizer=LemNormalize??, stop_words='english')
tfidf = tfidf_vec.fit_transform(tokens)
vals = cosine_similarity(tfidf[-1], tfidf)
idx = vals.argsort()[0][-2]
flat = vals.flatten()
flat.sort()
#req_tfidf = flat[-2]

'''
calcular tf-idf e similaridade por cosseno.

TfidfVec = TfidfVectorizer(tokenizer=LemNormalize, stop_words='english')
    tfidf = TfidfVec.fit_transform(sent_tokens)
    vals = cosine_similarity(tfidf[-1], tfidf)
    idx=vals.argsort()[0][-2]
    flat = vals.flatten()
    flat.sort()
    req_tfidf = flat[-2]
'''
# Out:
# 06-14 17:25:54.614	tuhm:twatchmanagerapplication.oncreate
# 06-14 17:25:54.625	tuhm:twatchmanagerapplication.appversion : 2.2.20.17113061
# 06-14 17:25:54.632	tuhm:setupwizardwelcomeactivity.uhm oncreate() intent: intent { act=android.intent.action.main cat=[android.intent.category.launcher] flg=0x10200000 cmp=com.samsung.android.app.watchmanager/.setupwizard.setupwizardwelcomeactivity launchparam=multiscreenlaunchparams { mdisplayid=0 mflags=0 } bnds=[694,471][949,789] (has extras) }
# 06-14 17:25:54.633	tuhm:setupwizardwelcomeactivity.uhm oncreate() bundle: null
# 06-14 17:25:54.633	tuhm:setupwizardwelcomeactivity.density [3.0], densitydpi [480], heightpixels [1920], widthpixels [1080]
# 06-14 17:25:54.642	tuhm:twatchmanagerapplication.getappcontext()
# 06-14 17:25:54.642	tuhm:twatchmanagerapplication.mappcontext = com.samsung.android.app.twatchmanager.twatchmanagerapplication@519f66b
# 06-14 17:25:54.643	tuhm:installationutils.hasinstallpermission() return:true
# ...
